# %%
import json
import numpy as np
import requests
import pandas as pd
from pandas.io.json import json_normalize

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
requestURL = "https://api.spotify.com/v1/playlists/6J9cAa313tYE4foIUNAGuR/tracks"
requestURL
# Out:
# 'https://api.spotify.com/v1/playlists/6J9cAa313tYE4foIUNAGuR/tracks'

# %%
token_string="BQCWjHDFzluGtZGyCGLiAO3XyHhJqt_XIHX2p33bhfZ9uiAnGZC6hgKFfdVzVTyNmS8YW6zqtlV6O8UnkRovHp058uilEGXJaJPZuovbvcDuiHALoztOXGH4847X0_otwZo31NjdNOap_Rv4dbXA-rkS6l7N5CkC1pO7mVoQ439Vte4ZqdQTgVQUom5mvVI5xQQM0WnMphC7WE16c40HXpdEoRLt2R3VCs1pW1iqBvET90mEJ6QDp8cxceg0_nqhmdApYTJ7m5tJ-w"
token_string
# Out:
# 'BQCWjHDFzluGtZGyCGLiAO3XyHhJqt_XIHX2p33bhfZ9uiAnGZC6hgKFfdVzVTyNmS8YW6zqtlV6O8UnkRovHp058uilEGXJaJPZuovbvcDuiHALoztOXGH4847X0_otwZo31NjdNOap_Rv4dbXA-rkS6l7N5CkC1pO7mVoQ439Vte4ZqdQTgVQUom5mvVI5xQQM0WnMphC7WE16c40HXpdEoRLt2R3VCs1pW1iqBvET90mEJ6QDp8cxceg0_nqhmdApYTJ7m5tJ-w'

# %%
headers = {"Authorization": "Bearer {}".format(token_string)}
headers
# Out:
# {'Authorization': 'Bearer BQCWjHDFzluGtZGyCGLiAO3XyHhJqt_XIHX2p33bhfZ9uiAnGZC6hgKFfdVzVTyNmS8YW6zqtlV6O8UnkRovHp058uilEGXJaJPZuovbvcDuiHALoztOXGH4847X0_otwZo31NjdNOap_Rv4dbXA-rkS6l7N5CkC1pO7mVoQ439Vte4ZqdQTgVQUom5mvVI5xQQM0WnMphC7WE16c40HXpdEoRLt2R3VCs1pW1iqBvET90mEJ6QDp8cxceg0_nqhmdApYTJ7m5tJ-w'}

# %%
r = requests.get(requestURL, headers=headers)
print(r.text)
# Out:
# {
#   "error": {
#     "status": 401,
#     "message": "The access token expired"
#   }
# }

# %%
dict=r.json()

# %%
df=json_normalize(dict['items'])
df.head()
# Out:
#                added_at                added_by.external_urls.spotify  \
# 0  2018-01-21T20:12:28Z  https://open.spotify.com/user/akshit.spotify
# 1  2018-01-21T20:13:58Z  https://open.spotify.com/user/akshit.spotify
# 2  2018-01-21T20:14:02Z  https://open.spotify.com/user/akshit.spotify
# 3  2018-01-21T20:14:05Z  https://open.spotify.com/user/akshit.spotify
# 4  2018-01-21T20:14:07Z  https://open.spotify.com/user/akshit.spotify
#
#                                      added_by.href     added_by.id  \
# 0  https://api.spotify.com/v1/users/akshit.spotify  akshit.spotify
# 1  https://api.spotify.com/v1/users/akshit.spotify  akshit.spotify
# 2  https://api.spotify.com/v1/users/akshit.spotify  akshit.spotify
# 3  https://api.spotify.com/v1/users/akshit.spotify  akshit.spotify
# 4  https://api.spotify.com/v1/users/akshit.spotify  akshit.spotify
#
#   added_by.type                 added_by.uri  is_local primary_color  \
# ...

# %%
playlist_df = df[['track.name','track.duration_ms','track.popularity','track.album.release_date','added_at']]

# %%
df_added_at = pd.DataFrame(pd.to_datetime(df['added_at']).apply(lambda x: x.date()))

# %%
type(df_added_at)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.concat([playlist_df,df_added_at], axis=1)
df.head()
# Out:
#                    track.name  track.duration_ms  track.popularity  \
# 0  El Sueño (feat. Tru-Skool)             234435                45
# 1                    Gangland             168000                 0
# 2                       Na Ja             208000                61
# 3                  Time Table             283627                42
# 4                     5 Taara             178421                 2
#
#   track.album.release_date              added_at    added_at
# 0               2017-10-19  2018-01-21T20:12:28Z  2018-01-21
# 1               2017-05-24  2018-01-21T20:13:58Z  2018-01-21
# 2               2017-02-21  2018-01-21T20:14:02Z  2018-01-21
# 3               2015-01-14  2018-01-21T20:14:05Z  2018-01-21
# 4               2015-12-18  2018-01-21T20:14:07Z  2018-01-21

# %%
df.head()
# Out:
#                    track.name  track.duration_ms  track.popularity  \
# 0  El Sueño (feat. Tru-Skool)             234435                45
# 1                    Gangland             168000                 0
# 2                       Na Ja             208000                61
# 3                  Time Table             283627                42
# 4                     5 Taara             178421                 2
#
#   track.album.release_date              added_at    added_at
# 0               2017-10-19  2018-01-21T20:12:28Z  2018-01-21
# 1               2017-05-24  2018-01-21T20:13:58Z  2018-01-21
# 2               2017-02-21  2018-01-21T20:14:02Z  2018-01-21
# 3               2015-01-14  2018-01-21T20:14:05Z  2018-01-21
# 4               2015-12-18  2018-01-21T20:14:07Z  2018-01-21

# %%
df = df.drop(df.columns[[5]], axis=1)

# %%
df.head()
# Out:
#                    track.name  track.duration_ms  track.popularity  \
# 0  El Sueño (feat. Tru-Skool)             234435                45
# 1                    Gangland             168000                 0
# 2                       Na Ja             208000                61
# 3                  Time Table             283627                42
# 4                     5 Taara             178421                 2
#
#   track.album.release_date
# 0               2017-10-19
# 1               2017-05-24
# 2               2017-02-21
# 3               2015-01-14
# 4               2015-12-18

# %%
abc = json_normalize(dict['items'])

# %%
import pprint

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
pp.pprint(dict['items'])
# Out:
# [   {   'added_at': '2018-01-21T20:12:28Z',
#         'added_by': {   'external_urls': {   'spotify': 'https://open.spotify.com/user/akshit.spotify'},
#                         'href': 'https://api.spotify.com/v1/users/akshit.spotify',
#                         'id': 'akshit.spotify',
#                         'type': 'user',
#                         'uri': 'spotify:user:akshit.spotify'},
#         'is_local': False,
#         'primary_color': None,
#         'track': {   'album': {   'album_type': 'single',
#                                   'artists': [   {   'external_urls': {   'spotify': 'https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR'},
#                                                      'href': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR',
#                                                      'id': '2FKWNmZWDBZR4dE5KX4plR',
#                                                      'name': 'Diljit Dosanjh',
# ...

# %%
pp.pprint(dict['items'][0]['track']['album']['artists'])
# Out:
# [   {   'external_urls': {   'spotify': 'https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR'},
#         'href': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR',
#         'id': '2FKWNmZWDBZR4dE5KX4plR',
#         'name': 'Diljit Dosanjh',
#         'type': 'artist',
#         'uri': 'spotify:artist:2FKWNmZWDBZR4dE5KX4plR'}]

# %%
l=[]
print(range(0,len(dict.keys())))
print(len(dict['items']))
for i in range(0,len(dict.keys())):
    #print(dict['items'][i]['track']['album']['artists'])
    #print("\n")
    innerl=[]
    for j in (dict['items'][i]['track']['album']['artists']):
        innerl.append(j['name'])
    l.append(innerl)
# Out:
# range(0, 7)
# 100
# ------
# ------
# ------
# ------
# ------
# ------
# ------
# [['Diljit Dosanjh'],
#  ['Mankirt Aulakh', 'Deep Kahlon'],
#  ['Pav Dharia'],
#  ['Kulwinder Billa'],
#  ['Diljit Dosanjh', 'Jatinder Shah'],
#  ['Garry Sandhu'],
#  ['Mankirt Aulakh', 'Desi Routz']]

# %%
listc=[]
for i in l:
    listc.append(", ".join(i))

# %%
artists = pd.DataFrame(listc)

# %%
artists
# Out:
#                                0
# 0                 Diljit Dosanjh
# 1    Mankirt Aulakh, Deep Kahlon
# 2                     Pav Dharia
# 3                Kulwinder Billa
# 4  Diljit Dosanjh, Jatinder Shah
# 5                   Garry Sandhu
# 6     Mankirt Aulakh, Desi Routz

# %%
for i in dict['items']:
    print(i)
    print(type(i))
    print("------")
    print("\n")
# Out:
# {'added_at': '2018-01-21T20:12:28Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/akshit.spotify'}, 'href': 'https://api.spotify.com/v1/users/akshit.spotify', 'id': 'akshit.spotify', 'type': 'user', 'uri': 'spotify:user:akshit.spotify'}, 'is_local': False, 'primary_color': None, 'track': {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR'}, 'href': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR', 'id': '2FKWNmZWDBZR4dE5KX4plR', 'name': 'Diljit Dosanjh', 'type': 'artist', 'uri': 'spotify:artist:2FKWNmZWDBZR4dE5KX4plR'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO'
# ...

# %%
abc
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6J9cAa313tYE4foIUNAGuR/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2018-01-21T20:12:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/akshit.spotify'},
#     'href': 'https://api.spotify.com/v1/users/akshit.spotify',
#     'id': 'akshit.spotify',
#     'type': 'user',
#     'uri': 'spotify:user:akshit.spotify'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR'},
#        'href': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR',
#        'id': '2FKWNmZWDBZR4dE5KX4plR',
#        'name': 'Diljit Dosanjh',
#        'type': 'artist',
#        'uri': 'spotify:artist:2FKWNmZWDBZR4dE5KX4plR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
# ...
