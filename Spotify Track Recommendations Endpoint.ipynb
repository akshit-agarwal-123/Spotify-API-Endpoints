# %%
import json
import numpy as np
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
requestURL = "https://api.spotify.com/v1/me/top/tracks?time_range=short_term&limit=50"

# %%
token_string = "BQCQAKZN2d5cV3xMtPeruG5ImMbYEWvI6X3vq3l3uHTCpowNcPrXrE8S7aaOw7mwNvU6d0nR8h5D8UmyUBRnk4n5D0eUcaQDW0621dRctRBAJXNdv1eUom4ZLdbDP9duB6CF_z9t92CpIsmfuQOrYt_riyR5fNgVoVylHWRYCQB4HyaUganZIF1BAzacfdmoFYSSy_0Mp7-ZJBnvLWIT0mMlHb1q_y9IEsGdHJHRH5EMySaiKoYz0G5PR5c03R0HnId4Mlntln0-8Q"

# %%
headers = {"Authorization": "Bearer {}".format(token_string)}
headers
# Out:
# {'Authorization': 'Bearer BQCQAKZN2d5cV3xMtPeruG5ImMbYEWvI6X3vq3l3uHTCpowNcPrXrE8S7aaOw7mwNvU6d0nR8h5D8UmyUBRnk4n5D0eUcaQDW0621dRctRBAJXNdv1eUom4ZLdbDP9duB6CF_z9t92CpIsmfuQOrYt_riyR5fNgVoVylHWRYCQB4HyaUganZIF1BAzacfdmoFYSSy_0Mp7-ZJBnvLWIT0mMlHb1q_y9IEsGdHJHRH5EMySaiKoYz0G5PR5c03R0HnId4Mlntln0-8Q'}

# %%
r = requests.get(requestURL, headers=headers)

# %%
print(r.text)
# Out:
# {
#   "items" : [ {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/61JrslREXq98hurYL2hYoc"
#         },
#         "href" : "https://api.spotify.com/v1/artists/61JrslREXq98hurYL2hYoc",
#         "id" : "61JrslREXq98hurYL2hYoc",
#         "name" : "Lata Mangeshkar",
#         "type" : "artist",
#         "uri" : "spotify:artist:61JrslREXq98hurYL2hYoc"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/1yzgJmZf5CxtFfGfRFm4Si"
#         },
#         "href" : "https://api.spotify.com/v1/artists/1yzgJmZf5CxtFfGfRFm4Si",
#         "id" : "1yzgJmZf5CxtFfGfRFm4Si",
#         "name" : "Gajendra Verma",
#         "type" : "artist",
#         "uri" : "spotify:artist:1yzgJmZf5CxtFfGfRFm4Si"
#       } ],
# ...

# %%
dict=r.json()

# %%
df =json_normalize(dict['items'])

# %%
df
# Out:
#    album.album_type                                      album.artists  \
# 0            SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# 1            SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# 2            SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# 3       COMPILATION  [{'external_urls': {'spotify': 'https://open.s...
# 4            SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# 5            SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# 6            SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# 7            SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# 8             ALBUM  [{'external_urls': {'spotify': 'https://open.s...
# 9            SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# 10      COMPILATION  [{'external_urls': {'spotify': 'https://open.s...
# 11           SINGLE  [{'external_urls': {'spotify': 'https://open.s...
# ...

# %%
affinity_df = df[['name','album.name','album.release_date','popularity','uri']]

# %%
affinity_df= affinity_df.sort_values(by=['popularity'],ascending=False)

# %%
affinity_df.columns = ['Track','Album','Release Date','Popularity','Spotify Identifier']
affinity_df.head(25)
affinity_df.reset_index(drop=True)
# Out:
#                                                 Track  \
# 0                                            Señorita
# 1                                      In My Feelings
# 2                                             Starboy
# 3                                               Sorry
# 4                                     SUBEME LA RADIO
# 5                                        Jack & Diane
# 6                                             Whistle
# 7   Bella Ciao - Música Original de la Serie la Ca...
# 8                          Bailando - Spanish Version
# 9   My Life Is Going On - Música Original De La Se...
# 10                                        Have It All
# 11                                       What Is Love
# 12                                   Dil Diyan Gallan
# 13                                Naina Da Kya Kasoor
# 14  Bella Ciao - Versión Lenta de la Música Origin...
# 15                                        Lamberghini
# ...
