# %%
import json
import numpy as np
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
requestURL = "https://api.spotify.com/v1/albums/24YQLIPPjDkkeNIFimSIGO/tracks"

# %%
token_string = "BQBBdEDaqHtfGHh_BxRIIofuLC78rsy73n5iLdmX55PNow4wAR1t7QmSIG8LozD-wlmrhhFSt0itkZ4QBet2LxFbdtsbJdW-oR8NQC0zHh8IdZDYAL8DQQukzL_PdScC3SzR3zIZMpsAPciLZmTz3s0"

# %%
headers = {"Authorization": "Bearer {}".format(token_string)}
headers
# Out:
# {'Authorization': 'Bearer BQBBdEDaqHtfGHh_BxRIIofuLC78rsy73n5iLdmX55PNow4wAR1t7QmSIG8LozD-wlmrhhFSt0itkZ4QBet2LxFbdtsbJdW-oR8NQC0zHh8IdZDYAL8DQQukzL_PdScC3SzR3zIZMpsAPciLZmTz3s0'}

# %%
r = requests.get(requestURL, headers=headers)

# %%
print(r.text)
# Out:
# {
#   "href" : "https://api.spotify.com/v1/albums/24YQLIPPjDkkeNIFimSIGO/tracks?offset=0&limit=20",
#   "items" : [ {
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw"
#       },
#       "href" : "https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw",
#       "id" : "7qG3b048QCHVRO5Pv1T5lw",
#       "name" : "Enrique Iglesias",
#       "type" : "artist",
#       "uri" : "spotify:artist:7qG3b048QCHVRO5Pv1T5lw"
#     }, {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/5luyt0SUvGkDMY4ILP6Qhl"
#       },
#       "href" : "https://api.spotify.com/v1/artists/5luyt0SUvGkDMY4ILP6Qhl",
#       "id" : "5luyt0SUvGkDMY4ILP6Qhl",
#       "name" : "Descemer Bueno",
#       "type" : "artist",
#       "uri" : "spotify:artist:5luyt0SUvGkDMY4ILP6Qhl"
#     }, {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/2cy1zPcrFcXAJTP0APWewL"
#       },
# ...

# %%
dict=r.json()

# %%
df =json_normalize(dict['items'],'artists')

# %%
df
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/7...
# 1   {'spotify': 'https://open.spotify.com/artist/5...
# 2   {'spotify': 'https://open.spotify.com/artist/2...
# 3   {'spotify': 'https://open.spotify.com/artist/7...
# 4   {'spotify': 'https://open.spotify.com/artist/3...
# 5   {'spotify': 'https://open.spotify.com/artist/4...
# 6   {'spotify': 'https://open.spotify.com/artist/7...
# 7   {'spotify': 'https://open.spotify.com/artist/7...
# 8   {'spotify': 'https://open.spotify.com/artist/0...
# 9   {'spotify': 'https://open.spotify.com/artist/7...
# 10  {'spotify': 'https://open.spotify.com/artist/3...
# 11  {'spotify': 'https://open.spotify.com/artist/7...
# 12  {'spotify': 'https://open.spotify.com/artist/3...
# 13  {'spotify': 'https://open.spotify.com/artist/7...
# 14  {'spotify': 'https://open.spotify.com/artist/7...
# 15  {'spotify': 'https://open.spotify.com/artist/7...
# ...

# %%
dict.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
dict.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
for key in dict.keys():
    print(key)
    
    print(dict[key])
    print("\n")
# Out:
# href
# https://api.spotify.com/v1/albums/24YQLIPPjDkkeNIFimSIGO/tracks?offset=0&limit=20
#
#
# items
# ...

# %%
type(dict['items'])
# Out:
# list

# %%
print(dict['items'][0]['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'}, 'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw', 'id': '7qG3b048QCHVRO5Pv1T5lw', 'name': 'Enrique Iglesias', 'type': 'artist', 'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5luyt0SUvGkDMY4ILP6Qhl'}, 'href': 'https://api.spotify.com/v1/artists/5luyt0SUvGkDMY4ILP6Qhl', 'id': '5luyt0SUvGkDMY4ILP6Qhl', 'name': 'Descemer Bueno', 'type': 'artist', 'uri': 'spotify:artist:5luyt0SUvGkDMY4ILP6Qhl'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cy1zPcrFcXAJTP0APWewL'}, 'href': 'https://api.spotify.com/v1/artists/2cy1zPcrFcXAJTP0APWewL', 'id': '2cy1zPcrFcXAJTP0APWewL', 'name': 'Gente De Zona', 'type': 'artist', 'uri': 'spotify:artist:2cy1zPcrFcXAJTP0APWewL'}]

# %%
for i in dict['items']:
    print(i.keys())
    print("\n")
# Out:
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri'])
#
#
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri'])
#
#
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri'])
#
#
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri'])
#
#
# dict_keys(['artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_urls', 'href', 'id', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri'])
#
#
# ...

# %%
print(dict['items'])
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'}, 'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw', 'id': '7qG3b048QCHVRO5Pv1T5lw', 'name': 'Enrique Iglesias', 'type': 'artist', 'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5luyt0SUvGkDMY4ILP6Qhl'}, 'href': 'https://api.spotify.com/v1/artists/5luyt0SUvGkDMY4ILP6Qhl', 'id': '5luyt0SUvGkDMY4ILP6Qhl', 'name': 'Descemer Bueno', 'type': 'artist', 'uri': 'spotify:artist:5luyt0SUvGkDMY4ILP6Qhl'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cy1zPcrFcXAJTP0APWewL'}, 'href': 'https://api.spotify.com/v1/artists/2cy1zPcrFcXAJTP0APWewL', 'id': '2cy1zPcrFcXAJTP0APWewL', 'name': 'Gente De Zona', 'type': 'artist', 'uri': 'spotify:artist:2cy1zPcrFcXAJTP0APWewL'}], 'available_markets': ['US'], 'disc_number': 1, 'duration_ms': 243346, 'explicit': False, 'external_urls': {'spotify': 'https://open.s
# ...

# %%
tracks_list=[]

for i in dict['items']:
    tracks_list.append(i['name'])
tracks_list
# Out:
# ['Bailando - Spanish Version',
#  "Tonight (I'm Fuckin' You)",
#  'Hero',
#  'I Like It',
#  'Cuando Me Enamoro',
#  'El Perdedor',
#  'Bailamos - From "Wild Wild West"',
#  'Escape',
#  'Be With You',
#  'Loco',
#  'Lloro Por Ti - Remix',
#  'Could I Have This Kiss Forever',
#  'No Me Digas Que No',
#  'Mentiroso',
#  '¿Dónde Están Corazón?',
#  'Bailando - English Version']

# %%
dict['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'},
#     'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw',
#     'id': '7qG3b048QCHVRO5Pv1T5lw',
#     'name': 'Enrique Iglesias',
#     'type': 'artist',
#     'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5luyt0SUvGkDMY4ILP6Qhl'},
#     'href': 'https://api.spotify.com/v1/artists/5luyt0SUvGkDMY4ILP6Qhl',
#     'id': '5luyt0SUvGkDMY4ILP6Qhl',
#     'name': 'Descemer Bueno',
#     'type': 'artist',
#     'uri': 'spotify:artist:5luyt0SUvGkDMY4ILP6Qhl'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cy1zPcrFcXAJTP0APWewL'},
#     'href': 'https://api.spotify.com/v1/artists/2cy1zPcrFcXAJTP0APWewL',
#     'id': '2cy1zPcrFcXAJTP0APWewL',
#     'name': 'Gente De Zona',
#     'type': 'artist',
#     'uri': 'spotify:artist:2cy1zPcrFcXAJTP0APWewL'}],
#   'available_markets': ['US'],
# ...

# %%
type(dict['items'][0])
for i in range(0,15):
    print(dict['items'][i])
    print("\n")
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'}, 'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw', 'id': '7qG3b048QCHVRO5Pv1T5lw', 'name': 'Enrique Iglesias', 'type': 'artist', 'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5luyt0SUvGkDMY4ILP6Qhl'}, 'href': 'https://api.spotify.com/v1/artists/5luyt0SUvGkDMY4ILP6Qhl', 'id': '5luyt0SUvGkDMY4ILP6Qhl', 'name': 'Descemer Bueno', 'type': 'artist', 'uri': 'spotify:artist:5luyt0SUvGkDMY4ILP6Qhl'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cy1zPcrFcXAJTP0APWewL'}, 'href': 'https://api.spotify.com/v1/artists/2cy1zPcrFcXAJTP0APWewL', 'id': '2cy1zPcrFcXAJTP0APWewL', 'name': 'Gente De Zona', 'type': 'artist', 'uri': 'spotify:artist:2cy1zPcrFcXAJTP0APWewL'}], 'available_markets': ['US'], 'disc_number': 1, 'duration_ms': 243346, 'explicit': False, 'external_urls': {'spotify': 'https://open.sp
# ...

# %%
print(dict['items'][0])
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'}, 'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw', 'id': '7qG3b048QCHVRO5Pv1T5lw', 'name': 'Enrique Iglesias', 'type': 'artist', 'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5luyt0SUvGkDMY4ILP6Qhl'}, 'href': 'https://api.spotify.com/v1/artists/5luyt0SUvGkDMY4ILP6Qhl', 'id': '5luyt0SUvGkDMY4ILP6Qhl', 'name': 'Descemer Bueno', 'type': 'artist', 'uri': 'spotify:artist:5luyt0SUvGkDMY4ILP6Qhl'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cy1zPcrFcXAJTP0APWewL'}, 'href': 'https://api.spotify.com/v1/artists/2cy1zPcrFcXAJTP0APWewL', 'id': '2cy1zPcrFcXAJTP0APWewL', 'name': 'Gente De Zona', 'type': 'artist', 'uri': 'spotify:artist:2cy1zPcrFcXAJTP0APWewL'}], 'available_markets': ['US'], 'disc_number': 1, 'duration_ms': 243346, 'explicit': False, 'external_urls': {'spotify': 'https://open.sp
# ...

# %%
type(dict['items'])
# Out:
# list

# %%
print(dict['items'][0]['artists'][0]['name'])#['artists'][0][name])
# Out:
# Enrique Iglesias

# %%
artists = []
for i in dict['items']:
    for j in (i['artists']):
        artists.append(j['name'])
len(artists)
# Out:
# 31

# %%
artists=[]
count=0
for i in dict['items']:
    #print(i['artists'])
    for j in i['artists']:
        print(j['name'])
        count=count+1
count
# Out:
# Enrique Iglesias
# Descemer Bueno
# Gente De Zona
# Enrique Iglesias
# Ludacris
# DJ Frank E
# Enrique Iglesias
# Enrique Iglesias
# Pitbull
# Enrique Iglesias
# Juan Luis Guerra 4.40
# Enrique Iglesias
# Marco Antonio Solís
# Enrique Iglesias
# Enrique Iglesias
# Enrique Iglesias
# Enrique Iglesias
# Romeo Santos
# Enrique Iglesias
# Wisin & Yandel
# Enrique Iglesias
# Whitney Houston
# Enrique Iglesias
# Wisin
# Yandel
# Enrique Iglesias
# Enrique Iglesias
# Enrique Iglesias
# Sean Paul
# Descemer Bueno
# Gente De Zona
# 31

# %%
print(dict['items'])

# %%
for i in dict['items']:
    print(i)
    print("-------------------------------------------------------------")
print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")

# %%
for i in dict['items'][0]['artists']:
    print(i)
    print("\n")

# %%
df = pd.DataFrame(dict['items'][0]['artists'])
df

# %%
pip install flatten_dict

# %%
from flatten_dict import flatten

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
client_id = "ae6d015addb94b8a985405dfb21d1015"
client_secret = "8a59fd0abeb149e785f92612ab16a167"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
name = "Pritam" #chosen artist
result = sp.search(name) #search query


result['tracks']['items'][5]['name']

# %%
len(result['tracks']['items'])

# %%
song_list=[]
for i in range(0,10):
    song_list.append(result['tracks']['items'][i]['name'])

# %%
song_list

# %%
def getSpotifyUserID(SpotifyURI,substring):
   return SpotifyURI.find(substring, SpotifyURI.find(substring) + 1)

# %%
x=getSpotifyUserID('spotify:track:1fPGJKSxywGzeyQ4hRECwJ',':')

# %%
su
# Out:
# 13
